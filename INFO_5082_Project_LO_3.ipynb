# %%
import pandas as panda
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as nump

#Reading Nationwide google mobility rates' Data from csv file using specfied columns
google_columns = [ 'year', 'month', 'day', 'gps_residential','gps_away_from_home']
file_path = "/Users/harikaporalla/Desktop/Harika's_MS_Courses/INFO_5082/Project/Project_Data/GoogleMobility-National-Daily.csv"
google_data = panda.read_csv(file_path,usecols=google_columns,skiprows = [1,2,3]) 


#printing the results of csv data reading
google_data.head(10)
# Out:
#    year  month  day  gps_residential  gps_away_from_home
# 0  2020      2   27         -0.00429             0.00701
# 1  2020      2   28         -0.00571             0.00839
# 2  2020      2   29         -0.00714             0.01090
# 3  2020      3    1         -0.00714             0.01090
# 4  2020      3    2         -0.00857             0.01260
# 5  2020      3    3         -0.01000             0.01400
# 6  2020      3    4         -0.01000             0.01400
# 7  2020      3    5         -0.01140             0.01540
# 8  2020      3    6         -0.01140             0.01540
# 9  2020      3    7         -0.01000             0.01290

# %%
#calling above function to read csv data with a file path
cov_case_cols = ['year', 'month', 'day', 'case_rate', 'new_case_rate']
file_path = "/Users/harikaporalla/Desktop/Harika's_MS_Courses/INFO_5082/Project/Project_Data/COVID-National-Daily.csv"
covid_cases_df = panda.read_csv(file_path, usecols = cov_case_cols,skiprows = [1,2,3,4,5,6],nrows = len(google_data.index))

#printing the results of csv data reading
covid_cases_df.tail(10)
# Out:
#      year  month  day  case_rate  new_case_rate
# 258  2020     10   11     2362.0           16.0
# 259  2020     10   12     2377.0           15.3
# 260  2020     10   13     2393.0           15.8
# 261  2020     10   14     2411.0           16.1
# 262  2020     10   15     2431.0           16.5
# 263  2020     10   16     2452.0           17.0
# 264  2020     10   17     2468.0           17.1
# 265  2020     10   18     2483.0           17.2
# 266  2020     10   19     2502.0           17.9
# 267  2020     10   20     2521.0           18.2

# %%
#Using function to print number of missing values in the dataset
def verifyMissingValuesInData(fileData):
    print(fileData.isnull().sum())
    return

#Calling above function to get total missing values in each data feature before cleaning
print("Total Missing or 'NaN' values in Google Mobility Data are: \n")
verifyMissingValuesInData(google_data)

google_data.tail(10)
# Out:
# Total Missing or 'NaN' values in Google Mobility Data are:
#
# year                  0
# month                 0
# day                   0
# gps_residential       0
# gps_away_from_home    0
# dtype: int64
#      year  month  day  gps_residential  gps_away_from_home
# 258  2020     11   11           0.0843             -0.0985
# 259  2020     11   12           0.0829             -0.0968
# 260  2020     11   13           0.0857             -0.0995
# 261  2020     11   14           0.0871             -0.1020
# 262  2020     11   15           0.0886             -0.1050
# 263  2020     11   16           0.0886             -0.1050
# 264  2020     11   17           0.0900             -0.1060
# 265  2020     11   18           0.0914             -0.1080
# 266  2020     11   19           0.0914             -0.1080
# 267  2020     11   20           0.0914             -0.1080

# %%
#Calling above function to get total missing values in each data feature of Covid cases before cleaning
print("Total Missing or 'NaN' values in Covid-19 cases dataset are: \n")
verifyMissingValuesInData(covid_cases_df)

covid_cases_df.tail(10)
# Out:
# Total Missing or 'NaN' values in Covid-19 cases dataset are:
#
# year             0
# month            0
# day              0
# case_rate        0
# new_case_rate    0
# dtype: int64
#      year  month  day  case_rate  new_case_rate
# 258  2020     10   11     2362.0           16.0
# 259  2020     10   12     2377.0           15.3
# 260  2020     10   13     2393.0           15.8
# 261  2020     10   14     2411.0           16.1
# 262  2020     10   15     2431.0           16.5
# 263  2020     10   16     2452.0           17.0
# 264  2020     10   17     2468.0           17.1
# 265  2020     10   18     2483.0           17.2
# 266  2020     10   19     2502.0           17.9
# 267  2020     10   20     2521.0           18.2

# %%
#Using functions to describe the dataset
def descData(fileData,name):
    print("\nDimension of the "+name+" dataset: \n",fileData.shape)
    print("\nData Types of the "+name+" dataset: \n",fileData.dtypes)
    print("\nView of the first 10 records of "+name+" dataset: \n",fileData.head(10))
    print("\nSummary of the "+name+" dataset: \n",fileData.describe())
    return

#Calling above function to print dataset description
descData(google_data,"Google Mobility")
# Out:
# Dimension of the Google Mobility dataset:
#  (268, 5)
#
# Data Types of the Google Mobility dataset:
#  year                    int64
# month                   int64
# day                     int64
# gps_residential       float64
# gps_away_from_home    float64
# dtype: object
#
# View of the first 10 records of Google Mobility dataset:
#     year  month  day  gps_residential  gps_away_from_home
# 0  2020      2   27         -0.00429             0.00701
# 1  2020      2   28         -0.00571             0.00839
# 2  2020      2   29         -0.00714             0.01090
# 3  2020      3    1         -0.00714             0.01090
# 4  2020      3    2         -0.00857             0.01260
# 5  2020      3    3         -0.01000             0.01400
# 6  2020      3    4         -0.01000             0.01400
# 7  2020      3    5         -0.01140             0.01540
# 8  2020      3    6         -0.01140             0.01540
# 9  2020      3    7         -0.01000             0.01290
#
# Summary of the Google Mobility dataset:
#           year       month         day  gps_residential  gps_away_from_home
# count   268.0  268.000000  268.000000       268.000000          268.000000
# mean   2020.0    6.787313   15.555970         0.095528           -0.112033
# std       0.0    2.547582    8.829674         0.046889            0.058257
# min    2020.0    2.000000    1.000000        -0.011400           -0.237000
# 25%    2020.0    5.000000    8.000000         0.072900           -0.140500
# 50%    2020.0    7.000000   15.000000         0.084300           -0.096700
# 75%    2020.0    9.000000   23.000000         0.120250           -0.083800
# max    2020.0   11.000000   31.000000         0.194000            0.015400

# %%
#Calling above function to print dataset description
descData(covid_cases_df,"Covid Cases")
# Out:
# Dimension of the Covid Cases dataset:
#  (268, 5)
#
# Data Types of the Covid Cases dataset:
#  year               int64
# month              int64
# day                int64
# case_rate        float64
# new_case_rate    float64
# dtype: object
#
# View of the first 10 records of Covid Cases dataset:
#     year  month  day  case_rate  new_case_rate
# 0  2020      1   27    0.00152       0.000174
# 1  2020      1   28    0.00152       0.000174
# 2  2020      1   29    0.00152       0.000174
# 3  2020      1   30    0.00183       0.000218
# 4  2020      1   31    0.00213       0.000218
# 5  2020      2    1    0.00244       0.000218
# 6  2020      2    2    0.00335       0.000261
# 7  2020      2    3    0.00335       0.000261
# 8  2020      2    4    0.00335       0.000261
# 9  2020      2    5    0.00366       0.000305
#
# Summary of the Covid Cases dataset:
#           year       month         day    case_rate  new_case_rate
# count   268.0  268.000000  268.000000   268.000000     268.000000
# mean   2020.0    5.768657   15.555970   865.398278       9.205623
# std       0.0    2.559887    8.829674   808.417364       6.170384
# min    2020.0    1.000000    1.000000     0.001520       0.000044
# 25%    2020.0    4.000000    8.000000    81.850000       6.360000
# 50%    2020.0    6.000000   15.000000   601.500000       8.955000
# 75%    2020.0    8.000000   23.000000  1617.000000      13.400000
# max    2020.0   10.000000   31.000000  2521.000000      20.200000

# %%
google_data.insert(0,'Date',['-'.join(i) for i in zip(google_data["year"].map(str),google_data["month"].map(str),google_data['day'].map(str))])
google_data['Date'] = panda.to_datetime(google_data['Date'], format='%Y-%m-%d')
google_data.set_index('Date', inplace=True, drop=False)
google_data = google_data.drop(google_data.columns[[0,1, 2, 3]], axis=1) 


google_data.head(10)
# Out:
#             gps_residential  gps_away_from_home
# Date
# 2020-02-27         -0.00429             0.00701
# 2020-02-28         -0.00571             0.00839
# 2020-02-29         -0.00714             0.01090
# 2020-03-01         -0.00714             0.01090
# 2020-03-02         -0.00857             0.01260
# 2020-03-03         -0.01000             0.01400
# 2020-03-04         -0.01000             0.01400
# 2020-03-05         -0.01140             0.01540
# 2020-03-06         -0.01140             0.01540
# 2020-03-07         -0.01000             0.01290

# %%
covid_cases_df.insert(0,'Date',['-'.join(i) for i in zip(covid_cases_df["year"].map(str),covid_cases_df["month"].map(str),covid_cases_df['day'].map(str))])
covid_cases_df['Date'] = panda.to_datetime(covid_cases_df['Date'], format='%Y-%m-%d')
covid_cases_df.set_index('Date', inplace=True, drop=False)
covid_cases_df = covid_cases_df.drop(covid_cases_df.columns[[0,1, 2, 3]], axis=1) 

covid_cases_df.head(10)
# Out:
#             case_rate  new_case_rate
# Date
# 2020-01-27    0.00152       0.000174
# 2020-01-28    0.00152       0.000174
# 2020-01-29    0.00152       0.000174
# 2020-01-30    0.00183       0.000218
# 2020-01-31    0.00213       0.000218
# 2020-02-01    0.00244       0.000218
# 2020-02-02    0.00335       0.000261
# 2020-02-03    0.00335       0.000261
# 2020-02-04    0.00335       0.000261
# 2020-02-05    0.00366       0.000305

# %%
path = "/Users/harikaporalla/Desktop/Harika's_MS_Courses/INFO_5082/Project/Processed_Project_Data/CleanGoogleMobility_data.csv"
google_data.to_csv(path,index=False)
google_data.head(5)
# Out:
#             gps_residential  gps_away_from_home
# Date
# 2020-02-27         -0.00429             0.00701
# 2020-02-28         -0.00571             0.00839
# 2020-02-29         -0.00714             0.01090
# 2020-03-01         -0.00714             0.01090
# 2020-03-02         -0.00857             0.01260

# %%
path = "/Users/harikaporalla/Desktop/Harika's_MS_Courses/INFO_5082/Project/Processed_Project_Data/Cleaned_Covid_Cases2_data.csv"
covid_cases_df.to_csv(path,index=False)
covid_cases_df.head(5)
# Out:
#             case_rate  new_case_rate
# Date
# 2020-01-27    0.00152       0.000174
# 2020-01-28    0.00152       0.000174
# 2020-01-29    0.00152       0.000174
# 2020-01-30    0.00183       0.000218
# 2020-01-31    0.00213       0.000218

# %%
lo3_data = panda.concat([google_data, covid_cases_df], axis=1, sort=False)

lo3_data.head(10)
# Out:
#             gps_residential  gps_away_from_home  case_rate  new_case_rate
# Date
# 2020-01-27              NaN                 NaN    0.00152       0.000174
# 2020-01-28              NaN                 NaN    0.00152       0.000174
# 2020-01-29              NaN                 NaN    0.00152       0.000174
# 2020-01-30              NaN                 NaN    0.00183       0.000218
# 2020-01-31              NaN                 NaN    0.00213       0.000218
# 2020-02-01              NaN                 NaN    0.00244       0.000218
# 2020-02-02              NaN                 NaN    0.00335       0.000261
# 2020-02-03              NaN                 NaN    0.00335       0.000261
# 2020-02-04              NaN                 NaN    0.00335       0.000261
# 2020-02-05              NaN                 NaN    0.00366       0.000305

# %%
print("\nVerifying Missing values in whole dataset: \n")
verifyMissingValuesInData(lo3_data)
lo3_data = lo3_data.dropna()

print(lo3_data.info())

verifyMissingValuesInData(lo3_data)
# Out:
# Verifying Missing values in whole dataset:
#
# gps_residential       31
# gps_away_from_home    31
# case_rate             31
# new_case_rate         31
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 237 entries, 2020-02-27 to 2020-10-20
# Freq: D
# Data columns (total 4 columns):
# gps_residential       237 non-null float64
# gps_away_from_home    237 non-null float64
# case_rate             237 non-null float64
# new_case_rate         237 non-null float64
# dtypes: float64(4)
# memory usage: 9.3 KB
# None
# gps_residential       0
# gps_away_from_home    0
# case_rate             0
# new_case_rate         0
# dtype: int64

# %%
# Univariate Plots for each time series variables
fig, axes = plt.subplots(nrows=2, ncols=2, dpi=120, figsize=(10,10))
for i, ax in enumerate(fig.axes):
    data = lo3_data[lo3_data.columns[i]]
    ax.plot(data, color='green', linewidth=1)
    ax.set_title(lo3_data.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout()
plt.savefig("/Users/harikaporalla/Desktop/Harika's_MS_Courses/INFO_5082/Project/univar_plot_LO3.png")
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows=2, ncols=1, figsize=(10,6))
plt.title('Hidden pattern from plot of lagged variables')
lo3_data.plot(ax=ax1)
panda.plotting.lag_plot(lo3_data)
plt.tight_layout()
plt.savefig("/Users/harikaporalla/Desktop/Harika's_MS_Courses/INFO_5082/Project/lag_plot_LO3.png")
plt.show()

# %%
#Splitting the dataset into Train and Test series

lo3_data_train = lo3_data[:int(0.8*(len(lo3_data)))]
lo3_data_test = lo3_data[int(0.8*(len(lo3_data))):]

print("Dimension for the Training Dataset: ",lo3_data_train.shape)
print("Dimension for the Testing Dataset: ",lo3_data_test.shape)
# Out:
# Dimension for the Training Dataset:  (189, 4)
# Dimension for the Testing Dataset:  (48, 4)

# %%
#Using function to run Augmented Dickey-Fuller Test (ADF Test) to check for stationarity in the dataset
from statsmodels.tsa.stattools import adfuller

def Stationary_test_ADF(dataset):
    for i in dataset.columns:
        print('\n ADF test for Column '+i+':\n')
        adf_test = adfuller(dataset[i], autolag='AIC')
        adf = panda.Series(adf_test[0:4], index = ['Test Statistic : ','p-value :','No_Lags : ','No_Obsv :'])

        for key, value in adf_test[4].items():
           adf['Critical Value (%s)'%key] = value
        print (adf)
    return
        
    
Stationary_test_ADF(lo3_data_train)
# Out:
#  ADF test for Column gps_residential:
#
# Test Statistic :         -3.051815
# p-value :                 0.030331
# No_Lags :                 8.000000
# No_Obsv :               180.000000
# Critical Value (1%)      -3.467211
# Critical Value (5%)      -2.877735
# Critical Value (10%)     -2.575403
# dtype: float64
#
#  ADF test for Column gps_away_from_home:
#
# Test Statistic :         -2.927372
# p-value :                 0.042256
# No_Lags :                 8.000000
# No_Obsv :               180.000000
# Critical Value (1%)      -3.467211
# Critical Value (5%)      -2.877735
# Critical Value (10%)     -2.575403
# dtype: float64
#
#  ADF test for Column case_rate:
#
# Test Statistic :          0.494387
# p-value :                 0.984702
# No_Lags :                 9.000000
# No_Obsv :               179.000000
# Critical Value (1%)      -3.467420
# Critical Value (5%)      -2.877826
# Critical Value (10%)     -2.575452
# dtype: float64
#
#  ADF test for Column new_case_rate:
#
# Test Statistic :         -2.494820
# p-value :                 0.116740
# No_Lags :                 9.000000
# No_Obsv :               179.000000
# Critical Value (1%)      -3.467420
# Critical Value (5%)      -2.877826
# Critical Value (10%)     -2.575452
# dtype: float64

# %%
# Differencing all variables to get rid of Stationarity
lo3_train_diff_1 = lo3_data_train.diff().dropna()
print('---------------------------------------After First Difference---------------------------------')
Stationary_test_ADF(lo3_train_diff_1)
# Out:
# ---------------------------------------After First Difference---------------------------------
#
#  ADF test for Column gps_residential:
#
# Test Statistic :         -3.299079
# p-value :                 0.014920
# No_Lags :                 6.000000
# No_Obsv :               181.000000
# Critical Value (1%)      -3.467005
# Critical Value (5%)      -2.877644
# Critical Value (10%)     -2.575355
# dtype: float64
#
#  ADF test for Column gps_away_from_home:
#
# Test Statistic :         -2.926638
# p-value :                 0.042337
# No_Lags :                 7.000000
# No_Obsv :               180.000000
# Critical Value (1%)      -3.467211
# Critical Value (5%)      -2.877735
# Critical Value (10%)     -2.575403
# dtype: float64
#
#  ADF test for Column case_rate:
#
# Test Statistic :         -2.290333
# p-value :                 0.175105
# No_Lags :                 8.000000
# No_Obsv :               179.000000
# Critical Value (1%)      -3.467420
# Critical Value (5%)      -2.877826
# Critical Value (10%)     -2.575452
# dtype: float64
#
#  ADF test for Column new_case_rate:
#
# Test Statistic :         -2.137117
# p-value :                 0.229854
# No_Lags :                 7.000000
# No_Obsv :               180.000000
# Critical Value (1%)      -3.467211
# Critical Value (5%)      -2.877735
# Critical Value (10%)     -2.575403
# dtype: float64

# %%
lo3_train_diff_1.plot(figsize=(10,6),linewidth = 5, fontsize = 12)
plt.title("First Differenced Series")
plt.savefig("/Users/harikaporalla/Desktop/Harika's_MS_Courses/INFO_5082/Project/I1_plot_LO3.png")
plt.show()

# %%
lo3_train_diff_2 = lo3_train_diff_1.diff().dropna()
print('------------------------------------------After Second Difference---------------------------------')
Stationary_test_ADF(lo3_train_diff_2)
# Out:
# ------------------------------------------After Second Difference---------------------------------
#
#  ADF test for Column gps_residential:
#
# Test Statistic :         -5.207111
# p-value :                 0.000009
# No_Lags :                 7.000000
# No_Obsv :               179.000000
# Critical Value (1%)      -3.467420
# Critical Value (5%)      -2.877826
# Critical Value (10%)     -2.575452
# dtype: float64
#
#  ADF test for Column gps_away_from_home:
#
# Test Statistic :         -4.735078
# p-value :                 0.000072
# No_Lags :                 9.000000
# No_Obsv :               177.000000
# Critical Value (1%)      -3.467845
# Critical Value (5%)      -2.878012
# Critical Value (10%)     -2.575551
# dtype: float64
#
#  ADF test for Column case_rate:
#
# Test Statistic :         -2.368730
# p-value :                 0.150757
# No_Lags :                 7.000000
# No_Obsv :               179.000000
# Critical Value (1%)      -3.467420
# Critical Value (5%)      -2.877826
# Critical Value (10%)     -2.575452
# dtype: float64
#
#  ADF test for Column new_case_rate:
#
# Test Statistic :       -6.114287e+00
# p-value :               9.173878e-08
# No_Lags :               7.000000e+00
# No_Obsv :               1.790000e+02
# Critical Value (1%)    -3.467420e+00
# Critical Value (5%)    -2.877826e+00
# Critical Value (10%)   -2.575452e+00
# dtype: float64

# %%
lo3_train_diff_2.plot(figsize=(10,6),linewidth = 5, fontsize = 12)
plt.title("Second Differenced Series")
plt.savefig("/Users/harikaporalla/Desktop/Harika's_MS_Courses/INFO_5082/Project/I2_plot_LO3.png")
plt.show()

# %%
lo3_train_diff_3 = lo3_train_diff_2.diff().dropna()
print('------------------------------------------After Third Difference---------------------------------')
Stationary_test_ADF(lo3_train_diff_3)
# Out:
# ------------------------------------------After Third Difference---------------------------------
#
#  ADF test for Column gps_residential:
#
# Test Statistic :       -1.328733e+01
# p-value :               7.482691e-25
# No_Lags :               4.000000e+00
# No_Obsv :               1.810000e+02
# Critical Value (1%)    -3.467005e+00
# Critical Value (5%)    -2.877644e+00
# Critical Value (10%)   -2.575355e+00
# dtype: float64
#
#  ADF test for Column gps_away_from_home:
#
# Test Statistic :       -6.587348e+00
# p-value :               7.258632e-09
# No_Lags :               1.300000e+01
# No_Obsv :               1.720000e+02
# Critical Value (1%)    -3.468952e+00
# Critical Value (5%)    -2.878495e+00
# Critical Value (10%)   -2.575809e+00
# dtype: float64
#
#  ADF test for Column case_rate:
#
# Test Statistic :        -18.952895
# p-value :                 0.000000
# No_Lags :                 6.000000
# No_Obsv :               179.000000
# Critical Value (1%)      -3.467420
# Critical Value (5%)      -2.877826
# Critical Value (10%)     -2.575452
# dtype: float64
#
#  ADF test for Column new_case_rate:
#
# Test Statistic :       -7.917126e+00
# p-value :               3.809745e-12
# No_Lags :               1.100000e+01
# No_Obsv :               1.740000e+02
# Critical Value (1%)    -3.468502e+00
# Critical Value (5%)    -2.878298e+00
# Critical Value (10%)   -2.575704e+00
# dtype: float64

# %%
lo3_train_diff_3.plot(figsize=(10,6),linewidth = 5, fontsize = 12)
plt.savefig("/Users/harikaporalla/Desktop/Harika's_MS_Courses/INFO_5082/Project/I3_plot_LO3.png")
plt.show()

# %%
from statsmodels.tsa.vector_ar.vecm import coint_johansen

#Using function to run cointegration test on all time series variables in the dataset.
def cointegration_test(df, alpha=0.05): 
    out = coint_johansen(df,1,3)
    eigens = out.lr2
    cvms = out.cvm[:, 1]

    print('TS variable  |    Max Eigen Test Statistic > or < C(95%)    |   Signif  \n')
    for col, eig, cvm in zip(df.columns, eigens, cvms):
        print(col, '-', round(eig,2), ">" if eig > cvm else "<", cvm, ' ->  ' , eig > cvm)


cointegration_test(lo3_train_diff_3)
# Out:
# TS variable  |    Max Eigen Test Statistic > or < C(95%)    |   Signif
#
# gps_residential - 145.29 > 30.8151  ->   True
# gps_away_from_home - 106.82 > 24.2522  ->   True
# case_rate - 93.82 > 17.1481  ->   True
# new_case_rate - 85.85 > 3.8415  ->   True

# %%
from statsmodels.tsa.stattools import grangercausalitytests

#Using function to run granger's causation matrix for time series variables in the dataset.
def grangers_causation_matrix(data, variables, test='ssr_chi2test', verbose=False):    
    df = panda.DataFrame(nump.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for c in df.columns:
        for r in df.index:
            test_result = grangercausalitytests(data[[r, c]], maxlag=7, verbose=False)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(7)]
            if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = nump.min(p_values)
            df.loc[r, c] = min_p_value
    df.columns = [var + '_x' for var in variables]
    df.index = [var + '_y' for var in variables]
    return df


grangers_causation_matrix(lo3_train_diff_3, variables = lo3_train_diff_3.columns)
# Out:
#                       gps_residential_x  gps_away_from_home_x  case_rate_x  \
# gps_residential_y                1.0000                0.0056       0.3679
# gps_away_from_home_y             0.0001                1.0000       0.3587
# case_rate_y                      0.1637                0.2347       1.0000
# new_case_rate_y                  0.6076                0.6384       0.1743
#
#                       new_case_rate_x
# gps_residential_y              0.0911
# gps_away_from_home_y           0.0935
# case_rate_y                    0.0044
# new_case_rate_y                1.0000

# %%
from statsmodels.tsa.vector_ar import vecm

vec_rank1 = vecm.select_coint_rank(lo3_data_train, det_order = 1, k_ar_diff = 7, method = 'trace', signif=0.05)
print(vec_rank1.summary())
# Out:
# Johansen cointegration test using trace test statistic with 5% significance level
# =====================================
# r_0 r_1 test statistic critical value
# -------------------------------------
#   0   4          79.19          55.25
#   1   4          37.81          35.01
#   2   4          14.39          18.40
# -------------------------------------

# %%
vec_rank2 = vecm.select_coint_rank(lo3_data_train, det_order = 1, k_ar_diff = 7, method = 'maxeig', signif=0.05)
print(vec_rank2.summary())
# Out:
# Johansen cointegration test using maximum eigenvalue test statistic with 5% significance level
# =====================================
# r_0 r_1 test statistic critical value
# -------------------------------------
#   0   1          41.38          30.82
#   1   2          23.42          24.25
# -------------------------------------

# %%
vecm_model = vecm.VECM(endog = lo3_data_train, k_ar_diff = 7, coint_rank = 3, deterministic = "ci")
vecm_model_fit = vecm_model.fit()
vecm_model_fit.predict(steps=len(lo3_data_test))
# Out:
# array([[ 7.16967315e-02, -8.13232604e-02,  1.86609910e+03,
#          1.20288210e+01],
#        [ 6.94055032e-02, -7.88280055e-02,  1.87830003e+03,
#          1.17090141e+01],
#        [ 6.71347848e-02, -7.55440143e-02,  1.88878319e+03,
#          1.14810284e+01],
#        [ 6.57405317e-02, -7.31925654e-02,  1.89782534e+03,
#          1.11983790e+01],
#        [ 6.38591420e-02, -7.10750063e-02,  1.90727258e+03,
#          1.10285369e+01],
#        [ 6.27629582e-02, -6.93827387e-02,  1.91645529e+03,
#          1.05160427e+01],
#        [ 5.96968480e-02, -6.57052499e-02,  1.92611389e+03,
#          1.03882963e+01],
#        [ 5.91401437e-02, -6.50511129e-02,  1.93595525e+03,
#          9.96393396e+00],
#        [ 5.78449373e-02, -6.34636551e-02,  1.94601239e+03,
#          9.67661260e+00],
#        [ 5.67328830e-02, -6.18555808e-02,  1.95418568e+03,
#          9.35055548e+00],
#        [ 5.51756359e-02, -5.94761498e-02,  1.96179683e+03,
#          9.12872173e+00],
#        [ 5.50364569e-02, -5.90392536e-02,  1.96890388e+03,
#          8.74627608e+00],
#        [ 5.37858985e-02, -5.77949662e-02,  1.97631446e+03,
#          8.57141114e+00],
#        [ 5.31646675e-02, -5.69493892e-02,  1.98384876e+03,
#          8.21622836e+00],
#        [ 5.19325137e-02, -5.55009588e-02,  1.99218366e+03,
#          8.00136652e+00],
#        [ 5.13565406e-02, -5.48342432e-02,  1.99993459e+03,
#          7.70773415e+00],
#        [ 5.00332143e-02, -5.30379127e-02,  2.00695744e+03,
#          7.53047500e+00],
#        [ 4.97020593e-02, -5.22429630e-02,  2.01293082e+03,
#          7.26825767e+00],
#        [ 4.85249366e-02, -5.07694777e-02,  2.01887537e+03,
#          7.13294558e+00],
#        [ 4.77201082e-02, -4.98027598e-02,  2.02477116e+03,
#          6.89370701e+00],
#        [ 4.64089035e-02, -4.82985296e-02,  2.03135022e+03,
#          6.76129409e+00],
#        [ 4.55244153e-02, -4.72564237e-02,  2.03814382e+03,
#          6.54397400e+00],
#        [ 4.40274559e-02, -4.54732795e-02,  2.04490487e+03,
#          6.41520682e+00],
#        [ 4.31239422e-02, -4.41172297e-02,  2.05071962e+03,
#          6.23263587e+00],
#        [ 4.17108729e-02, -4.21627904e-02,  2.05601950e+03,
#          6.13974368e+00],
#        [ 4.08035077e-02, -4.09321855e-02,  2.06089131e+03,
#          5.97449809e+00],
#        [ 3.94011809e-02, -3.92740802e-02,  2.06607636e+03,
#          5.88251261e+00],
#        [ 3.82315437e-02, -3.78746118e-02,  2.07159843e+03,
#          5.72227546e+00],
#        [ 3.67200368e-02, -3.61268468e-02,  2.07759475e+03,
#          5.61728358e+00],
#        [ 3.56135968e-02, -3.47147960e-02,  2.08326092e+03,
#          5.46319191e+00],
#        [ 3.41514683e-02, -3.27702435e-02,  2.08842237e+03,
#          5.37424654e+00],
#        [ 3.31627817e-02, -3.13262956e-02,  2.09284770e+03,
#          5.23777823e+00],
#        [ 3.18685670e-02, -2.96619606e-02,  2.09710236e+03,
#          5.15489957e+00],
#        [ 3.07918947e-02, -2.83417908e-02,  2.10141578e+03,
#          5.02288377e+00],
#        [ 2.94543138e-02, -2.68011795e-02,  2.10624449e+03,
#          4.92741562e+00],
#        [ 2.83666454e-02, -2.55149634e-02,  2.11126510e+03,
#          4.78871098e+00],
#        [ 2.70333565e-02, -2.38758258e-02,  2.11621220e+03,
#          4.69419968e+00],
#        [ 2.60560354e-02, -2.25106680e-02,  2.12054070e+03,
#          4.56965414e+00],
#        [ 2.49155673e-02, -2.09580297e-02,  2.12439258e+03,
#          4.48929722e+00],
#        [ 2.40107771e-02, -1.97524396e-02,  2.12791457e+03,
#          4.37822831e+00],
#        [ 2.29000991e-02, -1.84249430e-02,  2.13165173e+03,
#          4.29708263e+00],
#        [ 2.19414262e-02, -1.73171139e-02,  2.13570254e+03,
#          4.18317341e+00],
#        [ 2.08003570e-02, -1.60064139e-02,  2.14007430e+03,
#          4.09698663e+00],
#        [ 1.98849591e-02, -1.48509745e-02,  2.14426316e+03,
#          3.98852152e+00],
#        [ 1.88639509e-02, -1.34918417e-02,  2.14806064e+03,
#          3.91550448e+00],
#        [ 1.80747931e-02, -1.23748958e-02,  2.15132171e+03,
#          3.82591759e+00],
#        [ 1.71722183e-02, -1.12061565e-02,  2.15440907e+03,
#          3.76362083e+00],
#        [ 1.63891398e-02, -1.02582338e-02,  2.15758838e+03,
#          3.67980621e+00]])

# %%
forecast, lower, upper = vecm_model_fit.predict(len(lo3_data_test), 0.05)
forecast_df = panda.DataFrame(forecast, index = lo3_data_test.index, columns=lo3_data_test.columns+'_forecasted')
lower_df = panda.DataFrame(lower, index = lo3_data_test.index, columns=lo3_data_test.columns+'_lower')
upper_df = panda.DataFrame(upper, index = lo3_data_test.index, columns=lo3_data_test.columns+'_upper')


print('lower bounds of confidence intervals:')
print(lower.round(3))
print('\npoint forecasts:')
print(forecast.round(3))
print('\nupper bounds of confidence intervals:')
print(upper.round(3))
# Out:
# lower bounds of confidence intervals:
# [[ 6.800000e-02 -8.600000e-02  1.864379e+03  1.179500e+01]
#  [ 6.400000e-02 -8.500000e-02  1.875249e+03  1.128400e+01]
#  [ 5.900000e-02 -8.500000e-02  1.884121e+03  1.082400e+01]
#  [ 8.500000e-02  2.700000e-02  2.226453e+03  1.351800e+01]
#  [ 8.400000e-02  2.900000e-02  2.239624e+03  1.362000e+01]
#  [ 8.300000e-02  3.100000e-02  2.252168e+03  1.367200e+01]
#  [ 8.200000e-02  3.300000e-02  2.264607e+03  1.377700e+01]
#  [ 8.100000e-02  3.500000e-02  2.277177e+03  1.382900e+01]
#  [ 8.000000e-02  3.700000e-02  2.290400e+03  1.391800e+01]
#  [ 7.900000e-02  3.800000e-02  2.304011e+03  1.396100e+01]
#  [ 7.800000e-02  4.000000e-02  2.317769e+03  1.404800e+01]
#  [ 7.700000e-02  4.200000e-02  2.331088e+03  1.410300e+01]
#  [ 7.700000e-02  4.400000e-02  2.344057e+03  1.420200e+01]
#  [ 7.600000e-02  4.500000e-02  2.356778e+03  1.427100e+01]
#  [ 7.500000e-02  4.700000e-02  2.369810e+03  1.437000e+01]
#  [ 7.400000e-02  4.800000e-02  2.383294e+03  1.443500e+01]
#  [ 7.300000e-02  5.000000e-02  2.397290e+03  1.452800e+01]
#  [ 7.200000e-02  5.100000e-02  2.411309e+03  1.459700e+01]
#  [ 7.100000e-02  5.300000e-02  2.425119e+03  1.470100e+01]
#  [ 7.100000e-02  5.400000e-02  2.438524e+03  1.478800e+01]
#  [ 7.000000e-02  5.500000e-02  2.451857e+03  1.490200e+01]
#  [ 6.900000e-02  5.600000e-02  2.465385e+03  1.499500e+01]]

# %%
fig, axes = plt.subplots(2, 2, figsize=(12,20))

for i, (col,ax) in enumerate(zip(lo3_data.columns, fig.axes)):
    forecast_df[col+'_forecasted'].plot(legend=True, ax=ax).autoscale(axis='x',tight=True)
    lo3_data_test[col][-len(lo3_data_test):].plot(legend=True, ax=ax);
    ax.set_title(col + ": Forecast vs Actuals")
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout()
plt.show();

# %%
vecm_model_fit.plot_forecast(steps=len(lo3_data_test), n_last_obs=len(lo3_data_test))

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

def forecast_errors(fc_series,test_series):
    fc_errors = [test_series[i]-fc_series[i] for i in range(len(lo3_data_test))]
    bias = sum(fc_errors)*1.0/len(test_series)
    print(f'\n-> For Column "{test_series.name}":',"\n")
    print("  Bias:",bias)
    
    mae = mean_absolute_error(test_series,fc_series)
    print("\n  MAE:",mae)
    
    mse = mean_squared_error(test_series,fc_series)
    print("\n  MSE:",mse)
    
    print("\n  RMSE:",nump.sqrt(mse))
    
    return

for i in list(lo3_data_test.columns):
    forecast_errors(forecast_df[i+'_forecasted'],lo3_data_test[i])
# Out:
# -> For Column "gps_residential":
#
#   Bias: 0.026473952055046723
#
#   MAE: 0.026489454052084027
#
#   MSE: 0.0009510448072698859
#
#   RMSE: 0.0308390143692999
#
# -> For Column "gps_away_from_home":
#
#   Bias: -0.03478241653774513
#
#   MAE: 0.03480294009516818
#
#   MSE: 0.0016404802289565236
#
#   RMSE: 0.04050284223306463
#
# -> For Column "case_rate":
#
#   Bias: 125.55189789077501
#
#   MAE: 125.55189789077498
#
#   MSE: 27797.730717039278
#
#   RMSE: 166.72651473907587
#
# -> For Column "new_case_rate":
#
#   Bias: 6.677523185557898
#
#   MAE: 6.677523185557898
#
#   MSE: 62.94433162932878
#
#   RMSE: 7.933746380451595
