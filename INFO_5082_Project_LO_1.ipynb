# %%
import pandas as panda
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as nump

#Reading Customer Expenditure Data from csv file using specfied columns
afs_columns = ['freq', 'spend_all_inclow', 'spend_all_incmiddle', 'spend_all_inchigh', 'provisional']
file_path = "/Users/harikaporalla/Desktop/Harika's_MS_Courses/INFO_5082/Project/Project_Data/Affinity-National-Daily.csv"
afs_data = panda.read_csv(file_path) 

afs_data= afs_data.drop(afs_columns,axis=1)

total_nrows = len(afs_data.index)

#printing the results of csv data reading
afs_data.tail(10)
# Out:
#      year  month  day  spend_all  spend_apg  spend_aer  spend_grf  spend_hcs  \
# 292  2020     10   31    -0.0479    -0.1020     -0.555      0.123     -0.142
# 293  2020     11    1    -0.0624    -0.1050     -0.568      0.118     -0.135
# 294  2020     11    2    -0.0498    -0.1200     -0.536      0.127     -0.105
# 295  2020     11    3    -0.0530    -0.1360     -0.529      0.133     -0.191
# 296  2020     11    4    -0.0615    -0.1500     -0.526      0.116     -0.176
# 297  2020     11    5    -0.0651    -0.1550     -0.531      0.102     -0.180
# 298  2020     11    6    -0.0660    -0.1360     -0.528      0.105     -0.169
# 299  2020     11    7    -0.0592    -0.1230     -0.526      0.108     -0.163
# 300  2020     11    8    -0.0446    -0.1240     -0.517      0.114     -0.152
# 301  2020     11   15    -0.0283    -0.0341     -0.564      0.155     -0.135
#
#      spend_acf  spend_tws  spend_retail_no_grocery  spend_retail_w_grocery
# ...

# %%
#Reading Merchants/Business open percentage sata from csv file using specfied columns
wm_columns = ['merchants_inchigh', 'merchants_inclow', 'merchants_incmiddle']
file_path = "/Users/harikaporalla/Desktop/Harika's_MS_Courses/INFO_5082/Project/Project_Data/WomplyMerchants-National-Daily.csv"
wm_data = panda.read_csv(file_path,skiprows = [1,2,3],nrows=total_nrows)
wm_data= wm_data.drop(wm_columns,axis=1)


#printing the results of csv data reading
wm_data.head(10)
# Out:
#    year  month  day  merchants_all  merchants_ss40  merchants_ss60  \
# 0  2020      1   13       -0.00689        -0.00576        -0.00921
# 1  2020      1   14       -0.00854        -0.00749        -0.01020
# 2  2020      1   15       -0.01010        -0.00955        -0.01070
# 3  2020      1   16       -0.01110        -0.01050        -0.01100
# 4  2020      1   17       -0.00864        -0.00804        -0.00910
# 5  2020      1   18       -0.00513        -0.00438        -0.00600
# 6  2020      1   19       -0.00395        -0.00335        -0.00761
# 7  2020      1   20       -0.00129        -0.00104        -0.00471
# 8  2020      1   21       -0.00166        -0.00188        -0.00264
# 9  2020      1   22       -0.00340        -0.00279        -0.00601
#
#    merchants_ss65  merchants_ss70
# 0        -0.00734       -0.004830
# 1        -0.00873       -0.005540
# 2        -0.01010       -0.006760
# 3        -0.01100       -0.007620
# 4        -0.00864       -0.004850
# ...

# %%
#calling above function to read csv data with a file path 
wr_columns = ['revenue_inchigh', 'revenue_inclow', 'revenue_incmiddle']
file_path = "/Users/harikaporalla/Desktop/Harika's_MS_Courses/INFO_5082/Project/Project_Data/WomplyRevenue-National-Daily.csv" 
wr_data = panda.read_csv(file_path,skiprows = [1,2,3],nrows=total_nrows)
wr_data= wr_data.drop(wr_columns,axis=1)


#printing the results of csv data reading 
wr_data.head(10)
# Out:
#    year  month  day  revenue_all  revenue_ss40  revenue_ss60  revenue_ss65  \
# 0  2020      1   13    -0.020100      -0.01530     -0.017200      -0.03430
# 1  2020      1   14    -0.015100      -0.01190     -0.008520      -0.02730
# 2  2020      1   15    -0.011600      -0.00846     -0.000735      -0.02420
# 3  2020      1   16    -0.009310      -0.00955      0.001150      -0.02190
# 4  2020      1   17    -0.006110      -0.00629     -0.007700      -0.01850
# 5  2020      1   18    -0.003070      -0.00402     -0.006720      -0.01210
# 6  2020      1   19    -0.000157      -0.00644     -0.006160      -0.01370
# 7  2020      1   20     0.003420      -0.00151      0.005200      -0.00882
# 8  2020      1   21     0.005640      -0.00435      0.008550       0.00335
# 9  2020      1   22    -0.001500      -0.00587     -0.004550      -0.00990
#
#    revenue_ss70
# 0      -0.01930
# 1      -0.01290
# 2      -0.00886
# 3      -0.00517
# 4       0.00290
# 5       0.00494
# 6       0.01650
# ...

# %%
#Using functions to verify missing values in the dataset
def verifyMissingValuesInData(fileData):
    print(fileData.isnull().sum())
    return

#Calling above function to verify missing values and print results
print("Verifying Missing values in Spending dataset: \n")
verifyMissingValuesInData(afs_data)

print("\nVerifying Missing values in Merchants/Business Open Percentage dataset: \n")
verifyMissingValuesInData(wm_data)

print("\nVerifying Missing values in Buisnesses Revenue dataset: \n")
verifyMissingValuesInData(wr_data)
# Out:
# Verifying Missing values in Spending dataset:
#
# year                       0
# month                      0
# day                        0
# spend_all                  0
# spend_apg                  0
# spend_aer                  0
# spend_grf                  0
# spend_hcs                  0
# spend_acf                  0
# spend_tws                  0
# spend_retail_no_grocery    0
# spend_retail_w_grocery     0
# dtype: int64
#
# Verifying Missing values in Merchants/Business Open Percentage dataset:
#
# year              0
# month             0
# day               0
# merchants_all     0
# merchants_ss40    0
# merchants_ss60    0
# merchants_ss65    0
# merchants_ss70    0
# dtype: int64
#
# Verifying Missing values in Buisnesses Revenue dataset:
#
# year            0
# month           0
# day             0
# revenue_all     0
# revenue_ss40    0
# revenue_ss60    0
# revenue_ss65    0
# revenue_ss70    0
# dtype: int64

# %%
#Using functions to describe the dataset
def descData(fileData,name):
    print("\nDimension of the "+name+" dataset: \n",fileData.shape)
    print("\nData Types of the "+name+" dataset: \n",fileData.dtypes)
    print("\nView of the first 10 records of "+name+" dataset: \n",fileData.head(10))
    print("\nSummary of the "+name+" dataset: \n",fileData.describe())
    return

#Calling above function to print dataset description
descData(afs_data,"Customer Spending")

descData(wm_data,"Merchants/Businesses Open Percentage")

descData(wr_data,"Businesses Revenue")
# Out:
# Dimension of the Customer Spending dataset:
#  (302, 12)
#
# Data Types of the Customer Spending dataset:
#  year                         int64
# month                        int64
# day                          int64
# spend_all                  float64
# spend_apg                  float64
# spend_aer                  float64
# spend_grf                  float64
# spend_hcs                  float64
# spend_acf                  float64
# spend_tws                  float64
# spend_retail_no_grocery    float64
# spend_retail_w_grocery     float64
# dtype: object
#
# View of the first 10 records of Customer Spending dataset:
#     year  month  day  spend_all  spend_apg  spend_aer  spend_grf  spend_hcs  \
# 0  2020      1   13  -0.003010  -0.003150    -0.0335    0.01130   -0.02620
# 1  2020      1   14  -0.000435  -0.004320    -0.0511    0.01240    0.00826
# 2  2020      1   15   0.015400  -0.001820     0.0330    0.01480    0.03880
# ...

# %%
#afs_data['Date'] = ['-'.join(i) for i in zip(afs_data["Year"].map(str),afs_data["Month"].map(str),afs_data['Day'].map(str))]


afs_data.insert(0,'Date',['-'.join(i) for i in zip(afs_data["year"].map(str),afs_data["month"].map(str),afs_data['day'].map(str))])
afs_data['Date'] = panda.to_datetime(afs_data['Date'], format='%Y-%m-%d')
afs_data.set_index('Date', inplace=True, drop=False)
afs_data = afs_data.drop(afs_data.columns[[0,1, 2, 3]], axis=1) 


afs_data
# Out:
#             spend_all  spend_apg  spend_aer  spend_grf  spend_hcs  spend_acf  \
# Date
# 2020-01-13  -0.003010  -0.003150  -0.033500   0.011300   -0.02620  -0.004100
# 2020-01-14  -0.000435  -0.004320  -0.051100   0.012400    0.00826  -0.001880
# 2020-01-15   0.015400  -0.001820   0.033000   0.014800    0.03880  -0.000584
# 2020-01-16   0.022700  -0.000329   0.044000   0.020100    0.03580   0.002950
# 2020-01-17   0.001320  -0.016800   0.024800  -0.013800    0.02290  -0.005100
# 2020-01-18   0.001300  -0.020100   0.046600  -0.026400    0.01880  -0.007280
# 2020-01-19   0.011000  -0.013900   0.051500  -0.017000    0.01520   0.003720
# 2020-01-20   0.025200  -0.001510   0.050900   0.012000    0.01580   0.010900
# 2020-01-21   0.012400  -0.012400   0.040400  -0.001810    0.02580   0.001180
# 2020-01-22  -0.000322  -0.022900  -0.036200  -0.020900    0.02720  -0.014500
# 2020-01-23  -0.013200  -0.017700  -0.028300  -0.029600    0.01310  -0.013800
# ...

# %%
wm_data.insert(0,'Date',['-'.join(i) for i in zip(wm_data["year"].map(str),wm_data["month"].map(str),wm_data['day'].map(str))])
wm_data['Date'] = panda.to_datetime(wm_data['Date'], format='%Y-%m-%d')
wm_data.set_index('Date', inplace=True, drop=False)

wm_data = wm_data.drop(wm_data.columns[[0,1, 2, 3]], axis=1) 

wm_data.head(5)
# Out:
#             merchants_all  merchants_ss40  merchants_ss60  merchants_ss65  \
# Date
# 2020-01-13       -0.00689        -0.00576        -0.00921        -0.00734
# 2020-01-14       -0.00854        -0.00749        -0.01020        -0.00873
# 2020-01-15       -0.01010        -0.00955        -0.01070        -0.01010
# 2020-01-16       -0.01110        -0.01050        -0.01100        -0.01100
# 2020-01-17       -0.00864        -0.00804        -0.00910        -0.00864
#
#             merchants_ss70
# Date
# 2020-01-13        -0.00483
# 2020-01-14        -0.00554
# 2020-01-15        -0.00676
# 2020-01-16        -0.00762
# 2020-01-17        -0.00485

# %%
wr_data.insert(0,'Date',['-'.join(i) for i in zip(wr_data["year"].map(str),wr_data["month"].map(str),wr_data['day'].map(str))])
wr_data['Date'] = panda.to_datetime(wr_data['Date'], format='%Y-%m-%d')
wr_data.set_index('Date', inplace=True, drop=False)

wr_data = wr_data.drop(wr_data.columns[[0,1, 2, 3]], axis=1) 

wr_data.head(5)
# Out:
#             revenue_all  revenue_ss40  revenue_ss60  revenue_ss65  \
# Date
# 2020-01-13     -0.02010      -0.01530     -0.017200       -0.0343
# 2020-01-14     -0.01510      -0.01190     -0.008520       -0.0273
# 2020-01-15     -0.01160      -0.00846     -0.000735       -0.0242
# 2020-01-16     -0.00931      -0.00955      0.001150       -0.0219
# 2020-01-17     -0.00611      -0.00629     -0.007700       -0.0185
#
#             revenue_ss70
# Date
# 2020-01-13      -0.01930
# 2020-01-14      -0.01290
# 2020-01-15      -0.00886
# 2020-01-16      -0.00517
# 2020-01-17       0.00290

# %%
path = "/Users/harikaporalla/Desktop/Harika's_MS_Courses/INFO_5082/Project/Processed_Project_Data/CleanSpending_data.csv"
afs_data.to_csv(path,index=False)
afs_data.head(5)
# Out:
#             spend_all  spend_apg  spend_aer  spend_grf  spend_hcs  spend_acf  \
# Date
# 2020-01-13  -0.003010  -0.003150    -0.0335     0.0113   -0.02620  -0.004100
# 2020-01-14  -0.000435  -0.004320    -0.0511     0.0124    0.00826  -0.001880
# 2020-01-15   0.015400  -0.001820     0.0330     0.0148    0.03880  -0.000584
# 2020-01-16   0.022700  -0.000329     0.0440     0.0201    0.03580   0.002950
# 2020-01-17   0.001320  -0.016800     0.0248    -0.0138    0.02290  -0.005100
#
#             spend_tws  spend_retail_no_grocery  spend_retail_w_grocery
# Date
# 2020-01-13    0.00912                 0.000825                 0.00444
# 2020-01-14   -0.00121                 0.002680                 0.00609
# 2020-01-15    0.00906                 0.003590                 0.00757
# 2020-01-16    0.01860                 0.006140                 0.01120
# 2020-01-17    0.01640                -0.012000                -0.01260

# %%
path = "/Users/harikaporalla/Desktop/Harika's_MS_Courses/INFO_5082/Project/Processed_Project_Data/CleanWomMerchant_data.csv"
wm_data.to_csv(path,index=False)
wm_data.head(5)
# Out:
#             merchants_all  merchants_ss40  merchants_ss60  merchants_ss65  \
# Date
# 2020-01-13       -0.00689        -0.00576        -0.00921        -0.00734
# 2020-01-14       -0.00854        -0.00749        -0.01020        -0.00873
# 2020-01-15       -0.01010        -0.00955        -0.01070        -0.01010
# 2020-01-16       -0.01110        -0.01050        -0.01100        -0.01100
# 2020-01-17       -0.00864        -0.00804        -0.00910        -0.00864
#
#             merchants_ss70
# Date
# 2020-01-13        -0.00483
# 2020-01-14        -0.00554
# 2020-01-15        -0.00676
# 2020-01-16        -0.00762
# 2020-01-17        -0.00485

# %%
path = "/Users/harikaporalla/Desktop/Harika's_MS_Courses/INFO_5082/Project/Processed_Project_Data/CleanWomRevenue_data.csv"
wr_data.to_csv(path,index=False)
wr_data.head(5)
# Out:
#             revenue_all  revenue_ss40  revenue_ss60  revenue_ss65  \
# Date
# 2020-01-13     -0.02010      -0.01530     -0.017200       -0.0343
# 2020-01-14     -0.01510      -0.01190     -0.008520       -0.0273
# 2020-01-15     -0.01160      -0.00846     -0.000735       -0.0242
# 2020-01-16     -0.00931      -0.00955      0.001150       -0.0219
# 2020-01-17     -0.00611      -0.00629     -0.007700       -0.0185
#
#             revenue_ss70
# Date
# 2020-01-13      -0.01930
# 2020-01-14      -0.01290
# 2020-01-15      -0.00886
# 2020-01-16      -0.00517
# 2020-01-17       0.00290

# %%
lo1_data = panda.concat([afs_data, wm_data,wr_data], axis=1, sort=False)

lo1_data
# Out:
#             spend_all  spend_apg  spend_aer  spend_grf  spend_hcs  spend_acf  \
# Date
# 2020-01-13  -0.003010  -0.003150  -0.033500   0.011300   -0.02620  -0.004100
# 2020-01-14  -0.000435  -0.004320  -0.051100   0.012400    0.00826  -0.001880
# 2020-01-15   0.015400  -0.001820   0.033000   0.014800    0.03880  -0.000584
# 2020-01-16   0.022700  -0.000329   0.044000   0.020100    0.03580   0.002950
# 2020-01-17   0.001320  -0.016800   0.024800  -0.013800    0.02290  -0.005100
# 2020-01-18   0.001300  -0.020100   0.046600  -0.026400    0.01880  -0.007280
# 2020-01-19   0.011000  -0.013900   0.051500  -0.017000    0.01520   0.003720
# 2020-01-20   0.025200  -0.001510   0.050900   0.012000    0.01580   0.010900
# 2020-01-21   0.012400  -0.012400   0.040400  -0.001810    0.02580   0.001180
# 2020-01-22  -0.000322  -0.022900  -0.036200  -0.020900    0.02720  -0.014500
# 2020-01-23  -0.013200  -0.017700  -0.028300  -0.029600    0.01310  -0.013800
# ...

# %%
print("\nVerifying Missing values in whole dataset: \n")
verifyMissingValuesInData(lo1_data)
lo1_data = lo1_data.dropna()

print(lo1_data.info())

verifyMissingValuesInData(lo1_data)
# Out:
# Verifying Missing values in whole dataset:
#
# spend_all                  1
# spend_apg                  1
# spend_aer                  1
# spend_grf                  1
# spend_hcs                  1
# spend_acf                  1
# spend_tws                  1
# spend_retail_no_grocery    1
# spend_retail_w_grocery     1
# merchants_all              1
# merchants_ss40             1
# merchants_ss60             1
# merchants_ss65             1
# merchants_ss70             1
# revenue_all                1
# revenue_ss40               1
# revenue_ss60               1
# revenue_ss65               1
# revenue_ss70               1
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 301 entries, 2020-01-13 to 2020-11-08
# Data columns (total 19 columns):
# spend_all                  301 non-null float64
# spend_apg                  301 non-null float64
# spend_aer                  301 non-null float64
# spend_grf                  301 non-null float64
# ...

# %%
# Univariate Plots for each time series variables
fig, axes = plt.subplots(10, 2, figsize=(12,20))

fig.delaxes(axes[9,1])

for i, ax in enumerate(fig.axes):
    data = lo1_data[lo1_data.columns[i]]
    ax.plot(data, color='green', linewidth=1)
    ax.set_title(lo1_data.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)
    

plt.tight_layout()
plt.savefig("/Users/harikaporalla/Desktop/Harika's_MS_Courses/INFO_5082/Project/univar_plot_LO1.png")
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows=2, ncols=1, figsize=(10,6))
lo1_data.plot(ax=ax1)
panda.plotting.lag_plot(lo1_data)
plt.savefig("/Users/harikaporalla/Desktop/Harika's_MS_Courses/INFO_5082/Project/lag_plot_LO1.png")
plt.show()

# %%
#Using function to identify outliers in each variable of the dataset
def isOutlier(series, k=1.5):
    firstQuart = nump.percentile(series, 25)
    thridQuart = nump.percentile(series, 75)
    interQuart = thridQuart - firstQuart
    
    cut_off = interQuart * k
    lower, upper = firstQuart - cut_off, thridQuart + cut_off

    return [True if value < lower or value > upper else False for value in series]
    

#Calling above function to identify outliers in the dataset and creating new dataframe for results
outlier_data = lo1_data.apply(isOutlier, k=1.5)
outlier_data.head(10)
# Out:
#             spend_all  spend_apg  spend_aer  spend_grf  spend_hcs  spend_acf  \
# Date
# 2020-01-13      False      False       True      False      False       True
# 2020-01-14      False      False       True      False      False       True
# 2020-01-15      False      False       True      False      False       True
# 2020-01-16      False      False       True      False      False       True
# 2020-01-17      False      False       True       True      False       True
# 2020-01-18      False      False       True       True      False       True
# 2020-01-19      False      False       True       True      False       True
# 2020-01-20      False      False       True      False      False       True
# 2020-01-21      False      False       True       True      False       True
# 2020-01-22      False      False       True       True      False       True
#
#             spend_tws  spend_retail_no_grocery  spend_retail_w_grocery  \
# Date
# ...

# %%
#Replacing above detected outliers values with 'NaN'
for column in lo1_data:
    lo1_data[column] = nump.where(outlier_data[column] == True,'NaN',lo1_data[column])

#Converting the dataframe columns/variables to Numeric type
lo1_data[lo1_data.columns] = lo1_data[lo1_data.columns].apply(panda.to_numeric, errors='coerce')
lo1_data.head(10)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
#             spend_all  spend_apg  spend_aer  spend_grf  spend_hcs  spend_acf  \
# Date
# 2020-01-13  -0.003010  -0.003150        NaN     0.0113   -0.02620        NaN
# ...

# %%
#Filling all the 'NaN' values using linear method for interpolation
lo1_data = lo1_data.interpolate(method='linear', axis=0).bfill().ffill()

lo1_data.head(10)
# Out:
#             spend_all  spend_apg  spend_aer  spend_grf  spend_hcs  spend_acf  \
# Date
# 2020-01-13  -0.003010  -0.003150     -0.397   0.011300   -0.02620     -0.107
# 2020-01-14  -0.000435  -0.004320     -0.397   0.012400    0.00826     -0.107
# 2020-01-15   0.015400  -0.001820     -0.397   0.014800    0.03880     -0.107
# 2020-01-16   0.022700  -0.000329     -0.397   0.020100    0.03580     -0.107
# 2020-01-17   0.001320  -0.016800     -0.397   0.018075    0.02290     -0.107
# 2020-01-18   0.001300  -0.020100     -0.397   0.016050    0.01880     -0.107
# 2020-01-19   0.011000  -0.013900     -0.397   0.014025    0.01520     -0.107
# 2020-01-20   0.025200  -0.001510     -0.397   0.012000    0.01580     -0.107
# 2020-01-21   0.012400  -0.012400     -0.397   0.014720    0.02580     -0.107
# 2020-01-22  -0.000322  -0.022900     -0.397   0.017440    0.02720     -0.107
#
#             spend_tws  spend_retail_no_grocery  spend_retail_w_grocery  \
# Date
# ...

# %%
#Splitting the dataset into Train and Test series

no_obsv = int(0.8*(len(lo1_data)))

lo1_train = lo1_data[:no_obsv]
lo1_test = lo1_data[no_obsv:]

print("Dimension for the Training Dataset: ",lo1_train.shape)
print("Dimension for the Testing Dataset: ",lo1_test.shape)
# Out:
# Dimension for the Training Dataset:  (240, 19)
# Dimension for the Testing Dataset:  (61, 19)

# %%
#Using function to run Augmented Dickey-Fuller Test (ADF Test) to check for stationarity in the dataset
from statsmodels.tsa.stattools import adfuller

def Stationary_test_ADF(dataset):
    for i in dataset.columns:
        print("\n \nADF test for Column '"+i+"':")
        print('--------------------------------------')
        adf_test = adfuller(dataset[i], autolag='AIC')
        adf = panda.Series(adf_test[0:4], index = ['Test Statistic :','p-value :','No_lags :','No_Obsv :'])

        for key, value in adf_test[4].items():
           adf['Critical Value for %s : '%key] = value
        print (adf)
    return


Stationary_test_ADF(lo1_train)
# Out:
#
# ADF test for Column 'spend_all':
# --------------------------------------
# Test Statistic :              -2.231215
# p-value :                      0.195112
# No_lags :                     12.000000
# No_Obsv :                    227.000000
# Critical Value for 1% :       -3.459490
# Critical Value for 5% :       -2.874358
# Critical Value for 10% :      -2.573602
# dtype: float64
#
#
# ADF test for Column 'spend_apg':
# --------------------------------------
# Test Statistic :              -1.911889
# p-value :                      0.326489
# No_lags :                      9.000000
# No_Obsv :                    230.000000
# Critical Value for 1% :       -3.459106
# Critical Value for 5% :       -2.874190
# Critical Value for 10% :      -2.573512
# dtype: float64
#
#
# ADF test for Column 'spend_aer':
# --------------------------------------
# Test Statistic :              -1.820090
# p-value :                      0.370534
# No_lags :                      8.000000
# ...

# %%
lo1_train.plot(figsize=(10,6),linewidth = 5, fontsize = 12)
plt.savefig("/Users/harikaporalla/Desktop/Harika's_MS_Courses/INFO_5082/Project/I0_plot_LO1.png")
plt.show()

# %%
# Differencing all variables to get rid of Stationarity
data_diff_1 = lo1_train.diff().dropna()
print('---------------------------------------After First Difference---------------------------------')
Stationary_test_ADF(data_diff_1)
# Out:
# ---------------------------------------After First Difference---------------------------------
#
#
# ADF test for Column 'spend_all':
# --------------------------------------
# Test Statistic :            -5.987381e+00
# p-value :                    1.778846e-07
# No_lags :                    6.000000e+00
# No_Obsv :                    2.320000e+02
# Critical Value for 1% :     -3.458855e+00
# Critical Value for 5% :     -2.874080e+00
# Critical Value for 10% :    -2.573453e+00
# dtype: float64
#
#
# ADF test for Column 'spend_apg':
# --------------------------------------
# Test Statistic :              -3.697485
# p-value :                      0.004149
# No_lags :                      8.000000
# No_Obsv :                    230.000000
# Critical Value for 1% :       -3.459106
# Critical Value for 5% :       -2.874190
# Critical Value for 10% :      -2.573512
# dtype: float64
#
#
# ADF test for Column 'spend_aer':
# --------------------------------------
# ...

# %%
data_diff_1.plot(figsize=(10,6),linewidth = 5, fontsize = 12)
plt.savefig("/Users/harikaporalla/Desktop/Harika's_MS_Courses/INFO_5082/Project/I1_plot_LO1.png")
plt.show()

# %%
data_diff_2 = data_diff_1.diff().dropna()
print('------------------------------------After Second Difference---------------------------------')
Stationary_test_ADF(data_diff_2)
# Out:
# ------------------------------------After Second Difference---------------------------------
#
#
# ADF test for Column 'spend_all':
# --------------------------------------
# Test Statistic :            -7.984644e+00
# p-value :                    2.568346e-12
# No_lags :                    1.000000e+01
# No_Obsv :                    2.270000e+02
# Critical Value for 1% :     -3.459490e+00
# Critical Value for 5% :     -2.874358e+00
# Critical Value for 10% :    -2.573602e+00
# dtype: float64
#
#
# ADF test for Column 'spend_apg':
# --------------------------------------
# Test Statistic :            -7.492411e+00
# p-value :                    4.469506e-11
# No_lags :                    1.000000e+01
# No_Obsv :                    2.270000e+02
# Critical Value for 1% :     -3.459490e+00
# Critical Value for 5% :     -2.874358e+00
# Critical Value for 10% :    -2.573602e+00
# dtype: float64
#
#
# ADF test for Column 'spend_aer':
# --------------------------------------
# ...

# %%
data_diff_2.plot(figsize=(10,6),linewidth = 5, fontsize = 12)
plt.savefig("/Users/harikaporalla/Desktop/Harika's_MS_Courses/INFO_5082/Project/I2_plot_LO1.png")
plt.show()

# %%
from statsmodels.tsa.vector_ar.vecm import coint_johansen

#Using function to run cointegration test on all time series variables in the dataset.
def cointegration_test(df, alpha=0.05): 
    output = coint_johansen(df,1,2)
    eigens = output.lr2
    cvms = output.cvm[:, 1]
    print('TS variable  |    Max Eigen Test Statistic > or < C(95%)    |   Signif  \n')
    for col, eig, cvm in zip(df.columns, eigens, cvms):
        print(col, '-', round(eig,2), ">" if eig > cvm else "<", cvm, ' ->  ' , eig > cvm)


#Calling above function with stationary dataset
cointegration_test(data_diff_2)
# Out:
# TS variable  |    Max Eigen Test Statistic > or < C(95%)    |   Signif
#
# spend_all - 305.38 < nan  ->   False
# spend_apg - 294.17 < nan  ->   False
# spend_aer - 275.46 < nan  ->   False
# spend_grf - 265.22 < nan  ->   False
# spend_hcs - 248.23 < nan  ->   False
# spend_acf - 235.18 < nan  ->   False
# spend_tws - 205.07 < nan  ->   False
# spend_retail_no_grocery - 196.51 > 79.9878  ->   True
# spend_retail_w_grocery - 180.82 > 73.9355  ->   True
# merchants_all - 170.51 > 67.904  ->   True
# merchants_ss40 - 147.76 > 61.8051  ->   True
# merchants_ss60 - 141.0 > 55.7302  ->   True
# merchants_ss65 - 129.6 > 49.5875  ->   True
# merchants_ss70 - 113.07 > 43.4183  ->   True
# revenue_all - 107.96 > 37.1646  ->   True
# revenue_ss40 - 98.89 > 30.8151  ->   True
# revenue_ss60 - 80.06 > 24.2522  ->   True
# revenue_ss65 - 77.71 > 17.1481  ->   True
# revenue_ss70 - 57.64 > 3.8415  ->   True
# ...

# %%
from statsmodels.tsa.stattools import grangercausalitytests

#Using function to run granger's causation matrix for time series variables in the dataset.
def grangers_causation_matrix(data, columns, test='ssr_chi2test', verbose=False):    
    df = panda.DataFrame(nump.zeros((len(columns), len(columns))), columns=columns, index=columns)
    for c in df.columns:
        for r in df.index:
            test_result = grangercausalitytests(data[[r, c]], maxlag=14, verbose=False)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(14)]
            if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = min(p_values)
            df.loc[r, c] = min_p_value
    df.columns = [col + '_x' for col in columns]
    df.index = [col + '_y' for col in columns]
    return df

#Calling above function using differenced stationary dataset
grangers_causation_matrix(data_diff_2, data_diff_2.columns)
# Out:
#                            spend_all_x  spend_apg_x  spend_aer_x  spend_grf_x  \
# spend_all_y                     1.0000       0.0000       0.0040       0.0973
# spend_apg_y                     0.0000       1.0000       0.0322       0.0059
# spend_aer_y                     0.0052       0.0042       1.0000       0.0023
# spend_grf_y                     0.4246       0.0511       0.0003       1.0000
# spend_hcs_y                     0.0043       0.0178       0.0004       0.0129
# spend_acf_y                     0.0687       0.0000       0.0255       0.0259
# spend_tws_y                     0.0462       0.0204       0.0212       0.3717
# spend_retail_no_grocery_y       0.4109       0.0000       0.0261       0.0000
# spend_retail_w_grocery_y        0.0289       0.0000       0.0305       0.0000
# merchants_all_y                 0.0000       0.0000       0.0001       0.0180
# merchants_ss40_y                0.0000       0.0000       0.0000       0.0521
# ...

# %%
from statsmodels.tsa.api import VAR

model = VAR(endog=data_diff_2)
result = model.select_order(maxlags=7)
print(result.summary())
# Out:
#  VAR Order Selection (* highlights the minimums)
# ...
#       AIC         BIC         FPE         HQIC
# -------------------------------------------------
# 0      -177.2      -176.9   1.111e-77      -177.1
# 1      -183.1     -177.5*   3.006e-80      -180.8
# 2      -186.7      -175.6   9.127e-82     -182.2*
# 3      -187.6      -171.1   4.287e-82      -180.9
# 4      -189.1      -167.3   1.218e-82      -180.3
# 5      -190.4      -163.2   5.900e-83      -179.4
# 6      -192.0      -159.5   2.493e-83      -178.9
# 7     -194.4*      -156.4  8.990e-84*      -179.1
# -------------------------------------------------

# %%
#Fitting to a VAR model
model_fit = model.fit(7)

#Printing the summary of the VAR model results
model_fit.summary()
# Out:
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 08, Dec, 2020
# Time:                     10:23:58
# --------------------------------------------------------------------
# No. of Equations:         19.0000    BIC:                   -156.415
# Nobs:                     231.000    HQIC:                  -179.053
# Log likelihood:           18766.4    FPE:                8.98995e-84
# AIC:                     -194.356    Det(Omega_mle):     1.50946e-87
# --------------------------------------------------------------------
# Results for equation spend_all
# ...
#                                 coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------
# const                             -0.000087         0.000483           -0.180           0.857
# ...

# %%
from statsmodels.stats.stattools import durbin_watson
output_errors = durbin_watson(model_fit.resid)

print("-------Residuals------------- \n ")
for col, val in zip(lo1_data.columns, output_errors):
    print(col +' -> '+ str(val))
# Out:
# -------Residuals-------------
#
# spend_all -> 2.1490602629639555
# spend_apg -> 2.0181227598509364
# spend_aer -> 2.0005948827831386
# spend_grf -> 2.0483859313248334
# spend_hcs -> 2.0835529112995377
# spend_acf -> 2.0214397734597225
# spend_tws -> 2.3141742689059757
# spend_retail_no_grocery -> 2.170134305022987
# spend_retail_w_grocery -> 2.165872726246697
# merchants_all -> 2.100116444447363
# merchants_ss40 -> 2.0504474082381337
# merchants_ss60 -> 2.0085631954983363
# merchants_ss65 -> 1.9829072540961759
# merchants_ss70 -> 2.1360733834061305
# revenue_all -> 1.918972578195589
# revenue_ss40 -> 2.161196480516894
# revenue_ss60 -> 1.9794955574878432
# revenue_ss65 -> 2.045670639337524
# revenue_ss70 -> 1.8185221723747447

# %%
# Input/Test data for forecasting
forecast_input = data_diff_2.values[-model_fit.k_ar:]
print(forecast_input.shape)
# Out:
# (7, 19)

# %%
#Forecasted data values
fc_values = model_fit.forecast(y=forecast_input, steps=len(lo1_test))
fc_df = panda.DataFrame(fc_values, index=lo1_test.index, columns=lo1_test.columns+'_forecasted')
fc_df
# Out:
#             spend_all_forecasted  spend_apg_forecasted  spend_aer_forecasted  \
# Date
# 2020-09-09          1.339110e-02         -1.797590e-02          1.626309e-01
# 2020-09-10         -6.930636e-03          3.527527e-02         -4.954464e-02
# 2020-09-11          1.389399e-02         -4.533372e-02          8.086242e-02
# 2020-09-12         -4.443963e-03          2.457221e-02         -1.909519e-01
# 2020-09-13         -2.349012e-02         -5.681797e-02          1.623666e-01
# 2020-09-14          4.801525e-02          1.297021e-01         -2.051689e-01
# 2020-09-15         -2.262802e-02         -1.590885e-01          4.821784e-01
# 2020-09-16          2.402770e-02          1.981303e-01         -7.472596e-01
# 2020-09-17         -6.019159e-02         -3.014942e-01          8.922607e-01
# 2020-09-18          7.549853e-02          4.279394e-01         -1.209912e+00
# 2020-09-19         -1.021844e-01         -5.702090e-01          1.839040e+00
# ...

# %%
# Inverting the Differencing Transformation
def invert_transformation(ds, df_forecast):
    for col in ds.columns:
        # Inverting 2nd Differencing
        df_forecast[str(col)+'_firstDiff'] = (ds[col].iloc[-1] - ds[col].iloc[-2]) + df_forecast[str(col)+'_forecasted'].cumsum()

        # Inverting 1st Differencing
        df_forecast[str(col)+'_OrigForecast'] = ds[col].iloc[-1] + df_forecast[str(col)+'_firstDiff'].cumsum()

    return df_forecast

df_inverted = invert_transformation(lo1_train, fc_df)

df_inverted
# Out:
#             spend_all_forecasted  spend_apg_forecasted  spend_aer_forecasted  \
# Date
# 2020-09-09          1.339110e-02         -1.797590e-02          1.626309e-01
# 2020-09-10         -6.930636e-03          3.527527e-02         -4.954464e-02
# 2020-09-11          1.389399e-02         -4.533372e-02          8.086242e-02
# 2020-09-12         -4.443963e-03          2.457221e-02         -1.909519e-01
# 2020-09-13         -2.349012e-02         -5.681797e-02          1.623666e-01
# 2020-09-14          4.801525e-02          1.297021e-01         -2.051689e-01
# 2020-09-15         -2.262802e-02         -1.590885e-01          4.821784e-01
# 2020-09-16          2.402770e-02          1.981303e-01         -7.472596e-01
# 2020-09-17         -6.019159e-02         -3.014942e-01          8.922607e-01
# 2020-09-18          7.549853e-02          4.279394e-01         -1.209912e+00
# 2020-09-19         -1.021844e-01         -5.702090e-01          1.839040e+00
# ...

# %%
fig, axes = plt.subplots(10, 2, figsize=(12,20))

fig.delaxes(axes[9,1])
for i, (col,ax) in enumerate(zip(lo1_data.columns, fig.axes)):
    df_inverted[col+'_OrigForecast'].plot(legend=True, ax=ax).autoscale(axis='x',tight=True)
    lo1_test[col][-len(lo1_test):].plot(legend=True, ax=ax);
    ax.set_title(col + "- Forecast vs Actuals")
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)
    
    
plt.tight_layout()
plt.savefig("/Users/harikaporalla/Desktop/Harika's_MS_Courses/INFO_5082/Project/fc_Ac_LO1.png")
plt.show();

# %%
print(df_inverted.columns)
print(list(lo1_test.columns))
# Out:
# Index(['spend_all_forecasted', 'spend_apg_forecasted', 'spend_aer_forecasted',
#        'spend_grf_forecasted', 'spend_hcs_forecasted', 'spend_acf_forecasted',
#        'spend_tws_forecasted', 'spend_retail_no_grocery_forecasted',
#        'spend_retail_w_grocery_forecasted', 'merchants_all_forecasted',
#        'merchants_ss40_forecasted', 'merchants_ss60_forecasted',
#        'merchants_ss65_forecasted', 'merchants_ss70_forecasted',
#        'revenue_all_forecasted', 'revenue_ss40_forecasted',
#        'revenue_ss60_forecasted', 'revenue_ss65_forecasted',
#        'revenue_ss70_forecasted', 'spend_all_firstDiff',
#        'spend_all_OrigForecast', 'spend_apg_firstDiff',
#        'spend_apg_OrigForecast', 'spend_aer_firstDiff',
#        'spend_aer_OrigForecast', 'spend_grf_firstDiff',
#        'spend_grf_OrigForecast', 'spend_hcs_firstDiff',
#        'spend_hcs_OrigForecast', 'spend_acf_firstDiff',
#        'spend_acf_OrigForecast', 'spend_tws_firstDiff',
# ...

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

def Var_forecast_accuracy(fc_series, org_series):
    me = nump.mean(fc_series - org_series)             
    mae = nump.mean(nump.abs(fc_series - org_series))    
    mse = mean_squared_error(org_series,fc_series)   
    rmse = sqrt(mse)  
    residuals = [org_series[i]-fc_series[i] for i in range(len(org_series))]
    forecast_bias = sum(residuals)*1.0/len(org_series)
    return({'ME':me, 'MAE': mae, 
            'MSE': mse, 'RMSE':rmse,'Forecast_Bias':forecast_bias})

for col in list(lo1_test.columns):
    print('\nVAR Forecast Accuracy of '+col+':')
    accuracy_prod = Var_forecast_accuracy(df_inverted[col+'_OrigForecast'].values, lo1_test[col])
    for key, val in accuracy_prod.items():
        print(key +' -> '+str(round(val,6)))
# Out:
# VAR Forecast Accuracy of spend_all:
# ME -> -18276.770668
# MAE -> 104296.600443
# MSE -> 116275477858.10373
# RMSE -> 340991.902922
# Forecast_Bias -> 18276.770668
#
# VAR Forecast Accuracy of spend_apg:
# ME -> -97582.6345
# MAE -> 556869.466397
# MSE -> 3314780667218.08
# RMSE -> 1820653.911983
# Forecast_Bias -> 97582.6345
#
# VAR Forecast Accuracy of spend_aer:
# ME -> 296417.527342
# MAE -> 1691555.005281
# MSE -> 30585827666777.586
# RMSE -> 5530445.521545
# Forecast_Bias -> -296417.527342
#
# VAR Forecast Accuracy of spend_grf:
# ME -> 70509.58103
# MAE -> 402378.799372
# MSE -> 1730685137877.681
# RMSE -> 1315555.068356
# Forecast_Bias -> -70509.58103
#
# VAR Forecast Accuracy of spend_hcs:
# ME -> -562951.596488
# MAE -> 3212565.994613
# MSE -> 110319454448429.61
# RMSE -> 10503306.833966
# Forecast_Bias -> 562951.596488
#
# VAR Forecast Accuracy of spend_acf:
# ME -> 236539.080941
# MAE -> 1349846.604807
# MSE -> 19476765205110.773
# RMSE -> 4413248.826557
# ...

# %%
from statsmodels.tsa.vector_ar import vecm

vecm_model = vecm.VECM(endog = lo1_train, k_ar_diff = 7, coint_rank = 3, deterministic = "ci")
vecm_model_fit = vecm_model.fit()
vecm_model_fit.predict(steps=len(lo1_test))
# Out:
# array([[-1.06493944e-01, -1.39604077e-01, -6.15045410e-01, ...,
#         -1.94793810e-01, -2.60006648e-01, -5.03160341e-01],
#        [-1.14975780e-01, -1.47382491e-01, -5.97090295e-01, ...,
#         -2.21108951e-01, -3.19637292e-01, -4.77971424e-01],
#        [-1.12629981e-01, -1.36876123e-01, -4.92703873e-01, ...,
#         -1.57245366e-01, -2.00178994e-01, -5.63650833e-01],
#        ...,
#        [-1.53228148e+06, -1.22465981e+05,  5.07017947e+06, ...,
#          6.51226109e+06,  1.44941051e+07, -8.80347800e+06],
#        [ 2.16410307e+06,  1.72963688e+05, -7.16081996e+06, ...,
#         -9.19752949e+06, -2.04706099e+07,  1.24335060e+07],
#        [-3.05644999e+06, -2.44283627e+05,  1.01135139e+07, ...,
#          1.29900417e+07,  2.89114679e+07, -1.75603433e+07]])

# %%
forecast, lower, upper = vecm_model_fit.predict(len(lo1_test), 0.05)
forecast_df = panda.DataFrame(forecast, index = lo1_test.index, columns=lo1_test.columns+'_pred')
lower_df = panda.DataFrame(lower, index = lo1_test.index, columns=lo1_test.columns+'_lower')
upper_df = panda.DataFrame(upper, index = lo1_test.index, columns=lo1_test.columns+'_upper')


print('lower bounds of confidence intervals:')
print(lower.round(3))
print('\npoint forecasts:')
print(forecast.round(3))
print('\nupper bounds of confidence intervals:')
print(upper.round(3))
# Out:
# lower bounds of confidence intervals:
# [[-1.14000000e-01 -1.49000000e-01 -6.28000000e-01 ... -2.05000000e-01
#   -2.72000000e-01 -5.08000000e-01]
#  [-1.27000000e-01 -1.64000000e-01 -6.16000000e-01 ... -2.34000000e-01
#   -3.38000000e-01 -4.86000000e-01]
#  [-1.29000000e-01 -1.60000000e-01 -5.18000000e-01 ... -1.73000000e-01
#   -2.24000000e-01 -5.75000000e-01]
#  ...
#  [-1.60312426e+06 -1.28128014e+05  4.83576715e+06 ...  6.21117626e+06
#    1.38239915e+07 -9.21049384e+06]
#  [ 2.06404894e+06  1.64966963e+05 -7.49188992e+06 ... -9.62276375e+06
#   -2.14170384e+07  1.18586611e+07]
#  [-3.19776047e+06 -2.55577716e+05  9.64593038e+06 ...  1.23894662e+07
#    2.75747886e+07 -1.83722200e+07]]
#
# point forecasts:
# [[-1.06000000e-01 -1.40000000e-01 -6.15000000e-01 ... -1.95000000e-01
#   -2.60000000e-01 -5.03000000e-01]
#  [-1.15000000e-01 -1.47000000e-01 -5.97000000e-01 ... -2.21000000e-01
#   -3.20000000e-01 -4.78000000e-01]
# ...

# %%
fig, axes = plt.subplots(10, 2, figsize=(12,20))

fig.delaxes(axes[9,1])
for i, (col,ax) in enumerate(zip(lo1_data.columns, fig.axes)):
    forecast_df[col+'_pred'].plot(legend=True, ax=ax).autoscale(axis='x',tight=True)
    lo1_test[col][-len(lo1_test):].plot(legend=True, ax=ax);
    ax.set_title(col + ": Forecast vs Actuals")
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout()
plt.savefig("/Users/harikaporalla/Desktop/Harika's_MS_Courses/INFO_5082/Project/vecm_fc_Ac_LO1.png")
plt.show();

# %%
vecm_model_fit.plot_forecast(steps=len(lo1_test), n_last_obs=len(lo1_test))

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

def forecast_errors(fc_series,test_series):
    fc_errors = [test_series[i]-fc_series[i] for i in range(len(lo1_test))]
    bias = sum(fc_errors)*1.0/len(lo1_test)
    print(f'\n For "{test_series.name}"',"\n",'-'*50)
    print("\n Bias:",bias)
    
    mae = mean_absolute_error(test_series,fc_series)
    print("\n MAE:",mae)
    
    mse = mean_squared_error(test_series,fc_series)
    print("\n MSE:",mse)
    
    print("\n RMSE:",nump.sqrt(mse))
    
    return

for i in list(lo1_test.columns):
    forecast_errors(forecast_df[i+'_pred'],lo1_test[i])
# Out:
#  For "spend_all"
#  --------------------------------------------------
#
#  Bias: 29335.09985367587
#
#  MAE: 171621.22885641883
#
#  MSE: 307106547023.84155
#
#  RMSE: 554171.9471642728
#
#  For "spend_apg"
#  --------------------------------------------------
#
#  Bias: 2344.5193845384174
#
#  MAE: 13716.66134039582
#
#  MSE: 1961746994.7992518
#
#  RMSE: 44291.61314288803
#
#  For "spend_aer"
#  --------------------------------------------------
#
#  Bias: -97067.4087061053
#
#  MAE: 567878.9828995556
#
#  MSE: 3362471991228.365
#
#  RMSE: 1833704.444895187
#
#  For "spend_grf"
#  --------------------------------------------------
#
#  Bias: -32608.04274087149
#
#  MAE: 190769.24001159237
#
#  MSE: 379458006328.32605
#
#  RMSE: 616001.628511099
#
#  For "spend_hcs"
#  --------------------------------------------------
#
#  Bias: 378190.05957564357
#
#  MAE: 2212549.1432845257
#
#  MSE: 51042617005381.41
#
#  RMSE: 7144411.592663276
#
#  For "spend_acf"
# ...
